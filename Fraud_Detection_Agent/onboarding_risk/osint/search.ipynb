# %%
from googlesearch import search as _google_search
# Out:
# /Users/fds48354/.pyenv/versions/3.10.1/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.1.0)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %%
from duckduckgo_search import DDGS

results = DDGS().text("python programming", max_results=5)
print(results)
# Out:
# /var/folders/vr/cmqh14_940n7km9cxp5sqm2h0000gn/T/ipykernel_11022/1556922664.py:3: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   results = DDGS().text("python programming", max_results=5)
# []

# %%
_google_search("Nikhikil kamath, Zerodha",advanced=True)
# Out:
# <generator object search at 0x11407d230>

# %%
from googlesearch import search

# Iterate directly through the generator object
for url in search("Python programming", num_results=5):
    print(url)

# %%
j = _google_search("Nikhikil kamath, Zerodha", num_results=100, lang="en", ssl_verify=False)
for i in j:
    print(i)
# Out:
# /Users/fds48354/.pyenv/versions/3.10.1/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
results = list(_google_search("Nikhikil kamath, Zerodha", num_results=100, lang="en", ssl_verify=False))
print(results)
# Out:
# /Users/fds48354/.pyenv/versions/3.10.1/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# []

# %%
j = _google_search("Nikhilkil Kamath Zerodha", num_results=10)
results = list(j)
print(f"Found {len(results)} results")
print(results)
# Out:
# Found 0 results
# []

# %%
from duckduckgo_search import DDGS

with DDGS() as ddgs:
    results = ddgs.text("Python programming", max_results=5)
    for r in results:
        print(f"Title: {r['title']}\nURL: {r['href']}\nSnippet: {r['body']}\n")
# Out:
# /var/folders/vr/cmqh14_940n7km9cxp5sqm2h0000gn/T/ipykernel_11437/755293233.py:3: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:

# %%
from googlesearch import search

# Perform the search query
query = "Python programming"
results = search(query, num_results=5)

# Print the resulting URLs
for idx, url in enumerate(results, start=1):
    print(f"{idx}. {url}")
# Out:
# /Users/fds48354/.pyenv/versions/3.10.1/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.1.0)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %%
results
# Out:
# <generator object search at 0x11547f610>
